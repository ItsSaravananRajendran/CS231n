# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

w1 = np.load('/home/thunderbolt/NeuralNetworks/Linear/50.npy')
print np.count_nonzero(w1)
fig, ax = plt.subplots(nrows=2, ncols=5)
I = 0
for row in ax:
    for col in row:
        raw= w1[:3072,I]
        img = np.transpose(np.reshape(raw,(3, 32,32)), (1,2,0))
        col.imshow(img)
        I +=1
# Out:
# 30730

# %%
w1 = np.load('/home/thunderbolt/NeuralNetworks/TwoLayer/W1.npy')
fig, ax = plt.subplots(nrows=2, ncols=5)
I = 0
for row in ax:
    for col in row:
        raw= w1[:3072,I]
        img = np.transpose(np.reshape(raw,(3, 32,32)), (1,2,0))
        col.imshow(img)
        I +=1

# %%
w1 = np.load('/home/thunderbolt/NeuralNetworks/TwoLayer/W1.npy')
fig, ax = plt.subplots(nrows=2, ncols=5)
I = 70
for row in ax:
    for col in row:
        raw= w1[:3072,I]
        img = np.transpose(np.reshape(raw,(3, 32,32)), (1,2,0))
        col.imshow(img)
        I +=1

# %%
w1 = np.load('/home/thunderbolt/NeuralNetworks/Linear/OverFitting.npy')
fig, ax = plt.subplots(nrows=2, ncols=5)
I = 0
for row in ax:
    for col in row:
        raw= w1[:3072,I]
        img = np.transpose(np.reshape(raw,(3, 32,32)), (1,2,0))
        col.imshow(img)
        I +=1
